# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Weeks_Claimed_in_All_Programs.csv')

# %%
df.dropna(subset=["Total"])
df['Reflect_Week'] = pd.to_datetime(df['Reflect_Week'])
df['Year'] = df['Reflect_Week'].dt.year
df_18_21=df[df.Year>=2018]
df_18_21.drop('Year',axis='columns', inplace=True)
df_18_21
# Out:
# /Users/Tina/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      Reflect_Week      State     UCFE     UCX  EUC_1990  TEUC  EUC_08_Tier_I  \
# 1671   2018-01-13  2285327.0  11817.0  8495.0       NaN   NaN            NaN
# 1672   2018-01-20  2373111.0  14166.0  8654.0       NaN   NaN            NaN
# 1673   2018-01-27  2307488.0  12275.0  8826.0       NaN   NaN            NaN
# 1676   2018-02-17  2256241.0  12954.0  8196.0       NaN   NaN            NaN
# 1677   2018-02-24  2230032.0  11217.0  8341.0       NaN   NaN            NaN
# ...           ...        ...      ...     ...       ...   ...            ...
# 1858   2021-08-14  2796781.0   8977.0  6024.0       NaN   NaN            NaN
# 1859   2021-08-21  2662844.0   8298.0  5987.0       NaN   NaN            NaN
# 1860   2021-08-28  2656747.0   8723.0  6054.0       NaN   NaN            NaN
# 1863   2021-09-18  2463171.0   8365.0  5571.0       NaN   NaN            NaN
# 1864   2021-09-25  2397358.0   8479.0  5573.0       NaN   NaN            NaN
#
#       EUC_08_Tier_II  EUC_08_Tier_III  EUC_08_Tier_IV  EUC08_Total        EB  \
# 1671             NaN              NaN             NaN          NaN    1310.0
# 1672             NaN              NaN             NaN          NaN    1168.0
# 1673             NaN              NaN             NaN          NaN    1082.0
# 1676             NaN              NaN             NaN          NaN     964.0
# 1677             NaN              NaN             NaN          NaN     864.0
# ...              ...              ...             ...          ...       ...
# 1858             NaN              NaN             NaN          NaN  114357.0
# 1859             NaN              NaN             NaN          NaN  311337.0
# 1860             NaN              NaN             NaN          NaN   98730.0
# 1863             NaN              NaN             NaN          NaN  390656.0
# 1864             NaN              NaN             NaN          NaN  222613.0
#
#       State_AB      STC        PUA       PEUC       Total
# 1671    6132.0   8607.0        NaN        NaN   2321688.0
# 1672    6611.0  10389.0        NaN        NaN   2414099.0
# 1673    6703.0  11013.0        NaN        NaN   2347387.0
# 1676    6561.0   8945.0        NaN        NaN   2293861.0
# 1677    6896.0   8619.0        NaN        NaN   2265969.0
# ...        ...      ...        ...        ...         ...
# 1858    1030.0  45765.0  5413238.0  3800000.0  12186172.0
# 1859    1098.0  42694.0  5090524.0  3805008.0  11927790.0
# 1860    1063.0  42382.0  5487233.0  3805795.0  12106727.0
# 1863    1941.0  24231.0   647690.0   630814.0   4172439.0
# 1864    2036.0  23431.0   549103.0   440435.0   3649028.0
#
# [119 rows x 17 columns]

# %%
df_18_21["covid_UI"]=df_18_21["PUA"]+df_18_21["PEUC"]
df_18_21
# Out:
# <ipython-input-9-6d6738c66695>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18_21["covid_UI"]=df_18_21["PUA"]+df_18_21["PEUC"]
#      Reflect_Week      State     UCFE     UCX  EUC_1990  TEUC  EUC_08_Tier_I  \
# 1671   2018-01-13  2285327.0  11817.0  8495.0       NaN   NaN            NaN
# 1672   2018-01-20  2373111.0  14166.0  8654.0       NaN   NaN            NaN
# 1673   2018-01-27  2307488.0  12275.0  8826.0       NaN   NaN            NaN
# 1676   2018-02-17  2256241.0  12954.0  8196.0       NaN   NaN            NaN
# 1677   2018-02-24  2230032.0  11217.0  8341.0       NaN   NaN            NaN
# ...           ...        ...      ...     ...       ...   ...            ...
# 1858   2021-08-14  2796781.0   8977.0  6024.0       NaN   NaN            NaN
# 1859   2021-08-21  2662844.0   8298.0  5987.0       NaN   NaN            NaN
# 1860   2021-08-28  2656747.0   8723.0  6054.0       NaN   NaN            NaN
# 1863   2021-09-18  2463171.0   8365.0  5571.0       NaN   NaN            NaN
# 1864   2021-09-25  2397358.0   8479.0  5573.0       NaN   NaN            NaN
#
#       EUC_08_Tier_II  EUC_08_Tier_III  EUC_08_Tier_IV  EUC08_Total        EB  \
# 1671             NaN              NaN             NaN          NaN    1310.0
# 1672             NaN              NaN             NaN          NaN    1168.0
# 1673             NaN              NaN             NaN          NaN    1082.0
# 1676             NaN              NaN             NaN          NaN     964.0
# 1677             NaN              NaN             NaN          NaN     864.0
# ...              ...              ...             ...          ...       ...
# 1858             NaN              NaN             NaN          NaN  114357.0
# 1859             NaN              NaN             NaN          NaN  311337.0
# 1860             NaN              NaN             NaN          NaN   98730.0
# 1863             NaN              NaN             NaN          NaN  390656.0
# 1864             NaN              NaN             NaN          NaN  222613.0
#
#       State_AB      STC        PUA       PEUC       Total   covid_UI
# 1671    6132.0   8607.0        NaN        NaN   2321688.0        NaN
# 1672    6611.0  10389.0        NaN        NaN   2414099.0        NaN
# 1673    6703.0  11013.0        NaN        NaN   2347387.0        NaN
# 1676    6561.0   8945.0        NaN        NaN   2293861.0        NaN
# 1677    6896.0   8619.0        NaN        NaN   2265969.0        NaN
# ...        ...      ...        ...        ...         ...        ...
# 1858    1030.0  45765.0  5413238.0  3800000.0  12186172.0  9213238.0
# 1859    1098.0  42694.0  5090524.0  3805008.0  11927790.0  8895532.0
# 1860    1063.0  42382.0  5487233.0  3805795.0  12106727.0  9293028.0
# 1863    1941.0  24231.0   647690.0   630814.0   4172439.0  1278504.0
# 1864    2036.0  23431.0   549103.0   440435.0   3649028.0   989538.0
#
# [119 rows x 18 columns]

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.style.use('fivethirtyeight')
# df_18_21.plot(x='Reflect_Week',y='Total',color='red',linewidth = 2,fontsize = 8)
# df_18_21.plot(x='Reflect_Week',y='covid_UI',color='yellow',linewidth = 2,fontsize = 8)
plt.plot(df_18_21.Reflect_Week,df_18_21.Total,label = "All Programs")
plt.plot(df_18_21.Reflect_Week,df_18_21.covid_UI,label = "Covid UI")
plt.legend()
plt.show()
