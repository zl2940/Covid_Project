# %%
# Picked stimulus1_week12.xlsx, stimulus1_week22.xlsx, stimulus1_week27.xlsx 
# (corresponding to the dispersing time of three rounds of stimulus check) 
# Select the "Household income" for "Used, or will be used, mostly for expenses",
# "Used, or will be used, mostly to pay off debt" and "Used, or will be used, mostly to 
# add to savings" three columns and pasted together
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
income_df = pd.read_csv("household_income.csv")
labels = ['First round mostly for expense', 'mostly to pay off debt', 'mostly to add to savings', 'Second round mostly for expense', 'mostly to pay off debt', 'mostly to add to savings','Third round mostly for expense', 'mostly to pay off debt', 'Tmostly to add to savings']
less_49w=[income_df.iloc[:3,1:2].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,2:3].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,3:4].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,5:6].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,6:7].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,7:8].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,9:10].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,10:11].astype('int32').sum(axis=0).iat[0],income_df.iloc[:3,11:12].astype('int32').sum(axis=0).iat[0]]
less_149w=[income_df.iloc[3:6,1:2].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,2:3].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,3:4].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,5:6].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,6:7].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,7:8].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,9:10].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,10:11].astype('int32').sum(axis=0).iat[0],income_df.iloc[3:6,11:12].astype('int32').sum(axis=0).iat[0]]
more_150w=[income_df.iloc[6:,1:2].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,2:3].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,3:4].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,5:6].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,6:7].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,7:8].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,9:10].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,10:11].astype('int32').sum(axis=0).iat[0],income_df.iloc[6:,11:12].astype('int32').sum(axis=0).iat[0]]
data=[less_49w,less_149w,more_150w]
#print(more_150w)
x=range(len(labels))
width=0.35
bottom_y = [0] * len(labels)
sums = [sum(i) for i in zip(less_49w, less_149w, more_150w)]
#print(sums)
for i in data:
    y = [a/b for a,b in zip(i, sums)]
    plt.bar(x, y, width, bottom=bottom_y)
    bottom_y=[(a+b) for a, b in zip(y, bottom_y)]
    print(y)
# Household Stimulus Check Varied by Income Group For Each Round of Payment
plt.xticks(x, labels)
plt.show()
# Out:
# [0.511524504616448, 0.3655122273355727, 0.20325540147119217, 0.3977210299249652, 0.3034450863048518, 0.47861619262452837, 0.3618130350410125, 0.3330925721442703, 0.4524862288638464]
# [0.43304363902440945, 0.5417193572451415, 0.614172387779415, 0.5227269877641919, 0.5788734236479274, 0.47658142879393756, 0.5549350996714186, 0.573350047050693, 0.5007067646640417]
# [0.05543185635914248, 0.09276841541928578, 0.18257221074939287, 0.07955198231084287, 0.11768149004722087, 0.04480237858153407, 0.08325186528756892, 0.09355738080503669, 0.04680700647211191]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
income_df = pd.read_csv("household_income.csv")
labels = ['First Round', 'Second Round','Third Round']
most_spend=[income_df.iloc[:,1:2].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,5:6].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,9:10].astype('int32').sum(axis=0).iat[0]]
most_saved=[income_df.iloc[:,2:3].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,6:7].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,10:11].astype('int32').sum(axis=0).iat[0]]
most_paid=[income_df.iloc[:,3:4].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,7:8].astype('int32').sum(axis=0).iat[0],income_df.iloc[:,11:12].astype('int32').sum(axis=0).iat[0]]
data=[most_spend,most_saved,most_paid]
#print(more_150w)
x=range(len(labels))
width=0.35
bottom_y = [0] * len(labels)
sums = [sum(i) for i in zip(most_spend, most_saved, most_paid)]
#print(sums)
for i in data:
    y = [a/b for a,b in zip(i, sums)]
    plt.bar(x, y, width, bottom=bottom_y)
    bottom_y=[(a+b) for a, b in zip(y, bottom_y)]
    print(y)
# Share of Payment Recipents Using Money 
plt.xticks(x, labels)
plt.show()
# Out:
# [0.744284371782213, 0.22236015434074305, 0.19373619770140912]
# [0.14261532184815323, 0.2634823581914514, 0.3150207760965646]
# [0.11310030636963388, 0.5141574874678055, 0.4912430262020263]
