# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv('Weeks_Claimed_in_All_Programs_Unemployment.csv')

# %%
df.dropna(subset=["Total"])
df['Reflect_Week'] = pd.to_datetime(df['Reflect_Week'])
df['Year'] = df['Reflect_Week'].dt.year
df_18_21=df[df.Year>=2018]
df_18_21.drop('Year',axis='columns', inplace=True)
df_18_21
# Out:
# /Users/Tina/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      Reflect_Week      State     UCFE     UCX  EUC_1990  TEUC  EUC_08_Tier_I  \
# 1670   2018-01-06  2413748.0  14491.0  8738.0       NaN   NaN            NaN
# 1671   2018-01-13  2285327.0  11817.0  8495.0       NaN   NaN            NaN
# 1672   2018-01-20  2373111.0  14166.0  8654.0       NaN   NaN            NaN
# 1673   2018-01-27  2307488.0  12275.0  8826.0       NaN   NaN            NaN
# 1674   2018-02-03  2320540.0  13683.0  8453.0       NaN   NaN            NaN
# ...           ...        ...      ...     ...       ...   ...            ...
# 1862   2021-09-11  2500927.0   8481.0  5651.0       NaN   NaN            NaN
# ...

# %%
df_18_21["covid_UI"]=df_18_21["PUA"]+df_18_21["PEUC"]
df_18_21
# Out:
# <ipython-input-227-6d6738c66695>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_18_21["covid_UI"]=df_18_21["PUA"]+df_18_21["PEUC"]
#      Reflect_Week      State     UCFE     UCX  EUC_1990  TEUC  EUC_08_Tier_I  \
# 1670   2018-01-06  2413748.0  14491.0  8738.0       NaN   NaN            NaN
# 1671   2018-01-13  2285327.0  11817.0  8495.0       NaN   NaN            NaN
# 1672   2018-01-20  2373111.0  14166.0  8654.0       NaN   NaN            NaN
# 1673   2018-01-27  2307488.0  12275.0  8826.0       NaN   NaN            NaN
# 1674   2018-02-03  2320540.0  13683.0  8453.0       NaN   NaN            NaN
# ...           ...        ...      ...     ...       ...   ...            ...
# ...

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.style.use('fivethirtyeight')
# df_18_21.plot(x='Reflect_Week',y='Total',color='red',linewidth = 2,fontsize = 8)
# df_18_21.plot(x='Reflect_Week',y='covid_UI',color='yellow',linewidth = 2,fontsize = 8)
plt.plot(df_18_21.Reflect_Week,df_18_21.Total,label = "All Programs")
plt.plot(df_18_21.Reflect_Week,df_18_21.covid_UI,label = "Covid UI")
plt.legend()
plt.show()

# %%
# unemployment = pd.read_csv('dataset_percentage.csv')
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_18_21.Reflect_Week, df_18_21.covid_UI, color="red")
# set x-axis label
ax.set_xlabel("Reflect Week",fontsize=14)
# set y-axis label
ax.set_ylabel("covid UI",color="red",fontsize=14)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_18_21.Reflect_Week, df_18_21.Unemployment_Rate,color="blue",marker="o")
ax2.set_ylabel("Unemployment Rate",color="blue",fontsize=14)
plt.show()

# %%
df_18_21['covid_UI'].corr(df_18_21['Unemployment_Rate'])
# Out:
# -0.4947064895686914
